# %%
import pymongo
from pymongo import MongoClient
# connect to the default mongo instance aka: client = MongoClient('localhost', 27017)
# start mongo db with $mongod -dbpath . 
client = MongoClient()

# %%
print(client.database_names())
# Out:
# [u'admin', u'cache', u'liter', u'local']

# %%
import get_text
from get_text import download, genre_urls_dic, get_story

# %%
story_dict = genre_urls_dic('https://www.literotica.com/c/fetish-stories')[:200]

# %%
db = client.liter
collection = db.test

# %%
collection.insert_many(story_dict)

#collection.update_one({"story_id":"are-they-nice"},{'$set': {"tester":"test1"}})

# %%
from timeit import default_timer as timer
import multiprocessing as mp

story_list = collection.find(projection=['url'])



def get_it(story):
    client = MongoClient('localhost',27017,connect=False)
    db = client.liter
    collection = db.test
    collection.update_one({"_id":story['_id']},{"$set":get_story(story['url'])})

pool = mp.Pool()

start = timer()

pool.map(get_it, story_list)

end = timer()
print(end - start)
# Out:
# Process PoolWorker-1:
# Process PoolWorker-2:
# Process PoolWorker-4:
# Process PoolWorker-3:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/chase/anaconda3/envs/py2k/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/home/chase/anaconda3/envs/py2k/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#     self.run()
# Traceback (most recent call last):
#   File "/home/chase/anaconda3/envs/py2k/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/home/chase/anaconda3/envs/py2k/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/home/chase/anaconda3/envs/py2k/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/home/chase/anaconda3/envs/py2k/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self.run()
# ...

# %%
collection.find(projection=['url']).count()
# Out:
# 200

# %%
collection.delete_many({})

# %%
from pprint import pprint
pprint([x for x in collection.find()])
# Out:
# [{u'_id': ObjectId('5994e1a0e6624e1158914178'),
#   u'author_id': u'3254242',
#   u'author_name': u'FootnoteFetish',
#   u'created_date': datetime.datetime(2016, 7, 29, 0, 0),
#   u'desc': u"Indulging her husband's taste for shoes.",
#   u'genre': u'fetish-stories',
#   u'rating': 4.23,
#   u'story_id': u'are-they-nice',
#   u'title': u'"Are they Nice?"',
#   u'url': u'https://www.literotica.com/s/are-they-nice'},
#  {u'_id': ObjectId('5994e1a0e6624e1158914179'),
#   u'author_id': u'1344171',
#   u'author_name': u'SusanJillParker',
#   u'created_date': datetime.datetime(2014, 4, 17, 0, 0),
#   u'desc': u'Confessing secret, sexual fetishes in exchange for sex.',
#   u'genre': u'fetish-stories',
#   u'rating': 4.16,
#   u'story_id': u'oops-sorry-dean-flashes-wife-4',
#   u'title': u'"Oops, Sorry," Dean Flashes Wife #4',
#   u'url': u'https://www.literotica.com/s/oops-sorry-dean-flashes-wife-4'},
#  {u'_id': ObjectId('5994e1a0e6624e115891417a'),
#   u'author_id': u'569555',
# ...

# %%
text1 = get_story('https://www.literotica.com/s/3-days-of-watching-my-wife-fuck')
